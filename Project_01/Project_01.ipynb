# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import HTML

# %%
df = pd.read_csv("movies_complete.csv",parse_dates=["release_date"])

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44686         Rising and falling between a man and woman          NaT
# 44687                                                NaN   2011-11-17
# 44688                             A deadly game of wits.   2003-08-01
# 44689                                                NaN   1917-10-21
# 44690                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44686              Drama|Family                             NaN
# 44687                     Drama                             NaN
# 44688     Action|Drama|Thriller                             NaN
# 44689                       NaN                             NaN
# 44690                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 44686                fa          NaN           NaN
# 44687                tl          NaN           NaN
# 44688                en          NaN           NaN
# 44689                en          NaN           NaN
# 44690                en          NaN           NaN
#
#                                     production_companies  ... vote_average  \
# 0                                Pixar Animation Studios  ...          7.7
# 1      TriStar Pictures|Teitler Film|Interscope Commu...  ...          6.9
# 2                            Warner Bros.|Lancaster Gate  ...          6.5
# 3                 Twentieth Century Fox Film Corporation  ...          6.1
# 4              Sandollar Productions|Touchstone Pictures  ...          5.7
# ...                                                  ...  ...          ...
# 44686                                                NaN  ...          4.0
# 44687                                        Sine Olivia  ...          9.0
# 44688                            American World Pictures  ...          3.8
# 44689                                          Yermoliev  ...          NaN
# 44690                                                NaN  ...          NaN
#
#        popularity  runtime                                           overview  \
# 0       21.946943     81.0  Led by Woody, Andy's toys live happily in his ...
# 1       17.015539    104.0  When siblings Judy and Peter discover an encha...
# 2       11.712900    101.0  A family wedding reignites the ancient feud be...
# 3        3.859495    127.0  Cheated on, mistreated and stepped on, the wom...
# 4        8.387519    106.0  Just when George Banks has recovered from his ...
# ...           ...      ...                                                ...
# 44686    0.072051     90.0        Rising and falling between a man and woman.
# 44687    0.178241    360.0  An artist struggles to finish his work while a...
# 44688    0.903007     90.0  When one of her hits goes wrong, a professiona...
# 44689    0.003503     87.0  In a small town live two brothers, one a minis...
# 44690    0.163015     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                                        poster_path  \
# 0               English  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      English|Français  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2               English  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3               English  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4               English  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                 ...                                                ...
# 44686             فارسی  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687               NaN  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688           English  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689               NaN  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690           English  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                                     cast cast_size crew_size  \
# 0      Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13       106
# 1      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26        16
# 2      Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7         4
# 3      Whitney Houston|Angela Bassett|Loretta Devine|...        10        10
# 4      Steve Martin|Diane Keaton|Martin Short|Kimberl...        12         7
# ...                                                  ...       ...       ...
# 44686            Leila Hatami|Kourosh Tahami|Elham Korda         3         9
# 44687  Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...        11         6
# 44688  Erika Eleniak|Adam Baldwin|Julie du Page|James...        15         5
# 44689  Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...         5         2
# 44690                                                NaN         0         1
#
#                director
# 0         John Lasseter
# 1          Joe Johnston
# 2         Howard Deutch
# 3       Forest Whitaker
# 4         Charles Shyer
# ...                 ...
# 44686  Hamid Nematollah
# 44687          Lav Diaz
# 44688    Mark L. Lester
# 44689  Yakov Protazanov
# 44690     Daisy Asquith
#
# [44691 rows x 22 columns]

# %%
df.hist(figsize=(20,15), bins=100)
plt.show()

# %%
df.describe(include = "object")
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# top     Adaptation of the Jane Austen novel.          English
# freq                                       3            22189
#
#                                               poster_path            cast  \
# count                                               44467           42502
# unique                                              44456           42166
# top     <img src='http://image.tmdb.org/t/p/w185//qW1o...  Georges Méliès
# freq                                                    3              24
#
#          director
# count       43960
# unique      17349
# top     John Ford
# freq           66

# %%
df[df.title == "Cinderella"]
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
#                                       genres  belongs_to_collection  \
# 984         Family|Fantasy|Animation|Romance  Cinderella Collection
# 12988  TV Movie|Family|Fantasy|Music|Romance                    NaN
# 23254                          Fantasy|Drama                    NaN
# 23265               Animation|Family|Fantasy                    NaN
# 28073                        Family|TV Movie                    NaN
# 28340           Romance|Fantasy|Family|Drama                    NaN
# 33805                  Comedy|Family|Fantasy                    NaN
# 35114                          Drama|Romance                    NaN
# 35116                                    NaN                    NaN
# 40439  Fantasy|Horror|Science Fiction|Family                    NaN
# 44633                         Comedy|Romance                    NaN
#
#       original_language  budget_musd  revenue_musd  \
# 984                  en          2.9    263.591415
# 12988                en          NaN           NaN
# 23254                en          NaN           NaN
# 23265                en          NaN           NaN
# 28073                en          NaN           NaN
# 28340                en         95.0    543.514353
# 33805                ru          NaN           NaN
# 35114                en          NaN           NaN
# 35116                en          NaN           NaN
# 40439                fr          NaN           NaN
# 44633                ru          NaN           NaN
#
#                                     production_companies  ... vote_average  \
# 984           RKO Radio Pictures|Walt Disney Productions  ...          6.8
# 12988  Walt Disney Television|Citadel Entertainment|S...  ...          6.1
# 23254                                                NaN  ...          5.4
# 23265                            GoodTimes Entertainment  ...          6.0
# 28073  Beta Film|Lux Vide|ARD/Degeto Film GmbH|Rai Fi...  ...          5.3
# 28340  Walt Disney Pictures|Genre Films|Beagle Pug Fi...  ...          6.7
# 33805                                            Lenfilm  ...          4.8
# 35114                                                NaN  ...          5.9
# 35116                                                NaN  ...          5.6
# 40439                           Star-Film|Georges Méliès  ...          5.5
# 44633             Channel One Russia|Central Partnership  ...          4.6
#
#        popularity  runtime                                           overview  \
# 984     14.436858     74.0  Cinderella has faith her dreams of a better li...
# 12988    2.102013     88.0  Updated version of the classic Rodgers and Ham...
# 23254    0.361288     52.0  Based on Charles Perrault's fairy tale: Cinder...
# 23265    2.154873     48.0  Cinderella, the beautiful and kind-hearted rag...
# 28073    0.987462    180.0  Once upon a time in post-war Rome: 13-year old...
# 28340   19.801128    105.0  When her father unexpectedly passes away, youn...
# 33805    0.486073     80.0  Based on a classic fairytale "Cinderella" bril...
# 35114    0.209552     77.0  The first of three TV-versions of the classic ...
# 35116    1.085134     90.0  Cinderella (named Zezolla) and her family live...
# 40439    1.301063      5.0  A fairy godmother magically turns Cinderella's...
# 44633    0.803588     91.0  Masha Krapivina - is yet beautiful, and not th...
#
#        spoken_languages                                        poster_path  \
# 984             English  <img src='http://image.tmdb.org/t/p/w185//avz6...
# 12988           English  <img src='http://image.tmdb.org/t/p/w185//54aw...
# 23254           English  <img src='http://image.tmdb.org/t/p/w185//bL1K...
# 23265         Afrikaans  <img src='http://image.tmdb.org/t/p/w185//rbzG...
# 28073           English  <img src='http://image.tmdb.org/t/p/w185//wjZK...
# 28340           English  <img src='http://image.tmdb.org/t/p/w185//iH4C...
# 33805           Pусский  <img src='http://image.tmdb.org/t/p/w185//p41r...
# 35114           English  <img src='http://image.tmdb.org/t/p/w185//cB6I...
# 35116           English  <img src='http://image.tmdb.org/t/p/w185//gMYk...
# 40439       No Language  <img src='http://image.tmdb.org/t/p/w185//cf0g...
# 44633           Pусский  <img src='http://image.tmdb.org/t/p/w185//nvGe...
#
#                                                     cast cast_size crew_size  \
# 984    Ilene Woods|Eleanor Audley|Lucille Bliss|Verna...        11        50
# 12988  Brandy Norwood|Whitney Houston|Whoopi Goldberg...         5         1
# 23254  Mary Pickford|Owen Moore|Isabel Vernon|Georgia...         7         2
# 23265  Tony Ail|Nathan Aswell|Chera Bailey|Kathleen B...         7         3
# 28073  Vanessa Hessler|Flavio Parenti|Natalia Wörner|...        14        11
# 28340  Lily James|Cate Blanchett|Richard Madden|Helen...        78        80
# 33805  Yanina Zhejmo|Aleksei Konsovsky|Faina Ranevska...         6         4
# 35114  Julie Andrews|Howard Lindsay|Howard Lindsay|Il...         9        10
# 35116  Kathleen Turner|Katrin Cartlidge|David Warner|...        10         6
# 40439  Georges Méliès|Barral|Bleuette Bernon|Carmely|...         6         2
# 44633  Kristina Asmus|Nikita Efremov|Artyom Tkachenko...        18         4
#
#                    director
# 984          Clyde Geronimi
# 12988         Robert Iscove
# 23254        James Kirkwood
# 23265      Toshiyuki Hiruma
# 28073      Christian Duguay
# 28340       Kenneth Branagh
# 33805  Nadezhda Kosheverova
# 35114          Ralph Nelson
# 35116         Beeban Kidron
# 40439        Georges Méliès
# 44633         Sergey Ivanov
#
# [11 rows x 22 columns]

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd", "vote_count", "vote_average", "popularity"]].copy()

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story         30.0    373.554033      5415.0
# 1                          Jumanji         65.0    262.797249      2413.0
# 2                 Grumpier Old Men          NaN           NaN        92.0
# 3                Waiting to Exhale         16.0     81.452156        34.0
# 4      Father of the Bride Part II          NaN     76.578911       173.0
# ...                            ...          ...           ...         ...
# 44686                       Subdue          NaN           NaN         1.0
# 44687          Century of Birthing          NaN           NaN         3.0
# 44688                     Betrayal          NaN           NaN         6.0
# 44689             Satan Triumphant          NaN           NaN         0.0
# 44690                     Queerama          NaN           NaN         0.0
#
#        vote_average  popularity
# 0               7.7   21.946943
# 1               6.9   17.015539
# 2               6.5   11.712900
# 3               6.1    3.859495
# 4               5.7    8.387519
# ...             ...         ...
# 44686           4.0    0.072051
# 44687           9.0    0.178241
# 44688           3.8    0.903007
# 44689           NaN    0.003503
# 44690           NaN    0.163015
#
# [44691 rows x 7 columns]

# %%
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)

df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story         30.0    373.554033      5415.0
# 1                          Jumanji         65.0    262.797249      2413.0
# 2                 Grumpier Old Men          NaN           NaN        92.0
# 3                Waiting to Exhale         16.0     81.452156        34.0
# 4      Father of the Bride Part II          NaN     76.578911       173.0
# ...                            ...          ...           ...         ...
# 44686                       Subdue          NaN           NaN         1.0
# 44687          Century of Birthing          NaN           NaN         3.0
# 44688                     Betrayal          NaN           NaN         6.0
# 44689             Satan Triumphant          NaN           NaN         0.0
# 44690                     Queerama          NaN           NaN         0.0
#
#        vote_average  popularity  profit_musd     return
# 0               7.7   21.946943   343.554033  12.451801
# 1               6.9   17.015539   197.797249   4.043035
# 2               6.5   11.712900          NaN        NaN
# 3               6.1    3.859495    65.452156   5.090760
# 4               5.7    8.387519          NaN        NaN
# ...             ...         ...          ...        ...
# 44686           4.0    0.072051          NaN        NaN
# 44687           9.0    0.178241          NaN        NaN
# 44688           3.8    0.903007          NaN        NaN
# 44689           NaN    0.003503          NaN        NaN
# 44690           NaN    0.163015          NaN        NaN
#
# [44691 rows x 9 columns]

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", "Average Rating", "Popularity", "Profit", "ROI"]

# %%
df_best.set_index("Title", inplace = True)
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              Budget     Revenue   Votes  Average Rating  \
# Title
# Toy Story                      30.0  373.554033  5415.0             7.7
# Jumanji                        65.0  262.797249  2413.0             6.9
# Grumpier Old Men                NaN         NaN    92.0             6.5
# Waiting to Exhale              16.0   81.452156    34.0             6.1
# Father of the Bride Part II     NaN   76.578911   173.0             5.7
# ...                             ...         ...     ...             ...
# Subdue                          NaN         NaN     1.0             4.0
# Century of Birthing             NaN         NaN     3.0             9.0
# Betrayal                        NaN         NaN     6.0             3.8
# Satan Triumphant                NaN         NaN     0.0             NaN
# Queerama                        NaN         NaN     0.0             NaN
#
#                              Popularity      Profit        ROI
# Title
# Toy Story                     21.946943  343.554033  12.451801
# Jumanji                       17.015539  197.797249   4.043035
# Grumpier Old Men              11.712900         NaN        NaN
# Waiting to Exhale              3.859495   65.452156   5.090760
# Father of the Bride Part II    8.387519         NaN        NaN
# ...                                 ...         ...        ...
# Subdue                         0.072051         NaN        NaN
# Century of Birthing            0.178241         NaN        NaN
# Betrayal                       0.903007         NaN        NaN
# Satan Triumphant               0.003503         NaN        NaN
# Queerama                       0.163015         NaN        NaN
#
# [44691 rows x 8 columns]

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset = df_best.iloc[:5, :2]
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.0</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.0</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
#       <td>16.0</td>
#     </tr>
#     <tr>
#       <th>Father of the Bride Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_best.sort_values(by="Average Rating", ascending=False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# Satan Triumphant                            <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                                    <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                             Budget  Revenue  Votes  \
# Title
# Portrait of a Young Man in Three Movements     NaN      NaN    1.0
# Brave Revolutionary                            NaN      NaN    1.0
# Other Voices Other Rooms                       NaN      NaN    1.0
# The Lion of Thebes                             NaN      NaN    1.0
# Katt Williams: Priceless: Afterlife            NaN      NaN    2.0
# ...                                            ...      ...    ...
# Altar of Fire                                  NaN      NaN    0.0
# The Wonders of Aladdin                         NaN      NaN    0.0
# Deep Hearts                                    NaN      NaN    0.0
# Satan Triumphant                               NaN      NaN    0.0
# Queerama                                       NaN      NaN    0.0
#
#                                             Average Rating  Popularity  \
# Title
# Portrait of a Young Man in Three Movements            10.0    0.036471
# Brave Revolutionary                                   10.0    0.318826
# Other Voices Other Rooms                              10.0    0.036680
# The Lion of Thebes                                    10.0    1.783625
# Katt Williams: Priceless: Afterlife                   10.0    0.476007
# ...                                                    ...         ...
# Altar of Fire                                          NaN    0.000000
# The Wonders of Aladdin                                 NaN    0.093498
# Deep Hearts                                            NaN    0.011025
# Satan Triumphant                                       NaN    0.003503
# Queerama                                               NaN    0.163015
#
#                                             Profit  ROI
# Title
# Portrait of a Young Man in Three Movements     NaN  NaN
# Brave Revolutionary                            NaN  NaN
# Other Voices Other Rooms                       NaN  NaN
# The Lion of Thebes                             NaN  NaN
# Katt Williams: Priceless: Afterlife            NaN  NaN
# ...                                            ...  ...
# Altar of Fire                                  NaN  NaN
# The Wonders of Aladdin                         NaN  NaN
# Deep Hearts                                    NaN  NaN
# Satan Triumphant                               NaN  NaN
# Queerama                                       NaN  NaN
#
# [44691 rows x 8 columns]

# %%
df_best.loc[df_best.Budget>=5].sort_values(by="ROI",ascending=False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# Good Guys Go to Heaven, Bad Guys Go to Pattaya  <img src='http://image.tmdb.org/t/p/w185//cfVB...
# The Visitors: Bastille Day                      <img src='http://image.tmdb.org/t/p/w185//kBlm...
# House of the Long Shadows                       <img src='http://image.tmdb.org/t/p/w185//21ZG...
#
#                                                    Budget     Revenue   Votes  \
# Title
# E.T. the Extra-Terrestrial                      10.500000  792.965326  3359.0
# My Big Fat Greek Wedding                         5.000000  368.744044   686.0
# Star Wars                                       11.000000  775.398007  6778.0
# Jaws                                             7.000000  470.654000  2628.0
# Crocodile Dundee                                 5.000000  328.203506   512.0
# ...                                                   ...         ...     ...
# The Blonde with Bare Breasts                     7.500000         NaN     3.0
# Detroit                                         34.000000         NaN    67.0
# Good Guys Go to Heaven, Bad Guys Go to Pattaya   5.402000         NaN   153.0
# The Visitors: Bastille Day                      25.868826         NaN   167.0
# House of the Long Shadows                        7.500000         NaN    18.0
#
#                                                 Average Rating  Popularity  \
# Title
# E.T. the Extra-Terrestrial                                 7.3   19.358546
# My Big Fat Greek Wedding                                   6.2    6.719949
# Star Wars                                                  8.1   42.149697
# Jaws                                                       7.5   19.726114
# Crocodile Dundee                                           6.3    7.791212
# ...                                                        ...         ...
# The Blonde with Bare Breasts                               4.0    0.882188
# Detroit                                                    7.3    9.797505
# Good Guys Go to Heaven, Bad Guys Go to Pattaya             5.3    5.613875
# The Visitors: Bastille Day                                 4.0    7.294920
# House of the Long Shadows                                  6.1    1.185515
#
#                                                     Profit        ROI
# Title
# E.T. the Extra-Terrestrial                      782.465326  75.520507
# My Big Fat Greek Wedding                        363.744044  73.748809
# Star Wars                                       764.398007  70.490728
# Jaws                                            463.654000  67.236286
# Crocodile Dundee                                323.203506  65.640701
# ...                                                    ...        ...
# The Blonde with Bare Breasts                           NaN        NaN
# Detroit                                                NaN        NaN
# Good Guys Go to Heaven, Bad Guys Go to Pattaya         NaN        NaN
# The Visitors: Bastille Day                             NaN        NaN
# House of the Long Shadows                              NaN        NaN
#
# [5449 rows x 8 columns]

# %%
df_best.Budget.fillna(0, inplace= True)
df_best.Votes.fillna(0, inplace= True)

# %%
def best_worst(n, by, ascending= False, min_bud = 0, min_votes = 0):
    
    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes),["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return HTML(df2.to_html(escape = False))

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(n=5, by= "Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.0</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.0</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.0</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6ZYOpyhFZrAQIe1BuhqVgzfAdGZ.jpg' style='height:100px;'></td>
#       <td>270.0</td>
#     </tr>
#     <tr>
#       <th>Transformers: The Last Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//s5HQf2Gb3lIO2cRcFwNL9sn1o1o.jpg' style='height:100px;'></td>
#       <td>260.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(n = 5, by = "Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.965087</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.223624</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.034188</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1519.557910</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rhr4y79GpxQF9IsfJItRXVaoGs4.jpg' style='height:100px;'></td>
#       <td>1513.528810</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(n =5, by = "Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.965087</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.223624</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.034188</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rhr4y79GpxQF9IsfJItRXVaoGs4.jpg' style='height:100px;'></td>
#       <td>1363.528810</td>
#     </tr>
#     <tr>
#       <th>Furious 7</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d9jZ2bKZw3ptTuxAyVHA6olPAVs.jpg' style='height:100px;'></td>
#       <td>1316.249360</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(n=5, by="Profit", ascending="True")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.710090</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.180039</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.007242</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jfIpMh79fGRqYJ6PwZLCntzgxlF.jpg' style='height:100px;'></td>
#       <td>-107.447384</td>
#     </tr>
#     <tr>
#       <th>The 13th Warrior</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7pyhR5K1iv67daYw0DfsmsersKA.jpg' style='height:100px;'></td>
#       <td>-98.301101</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(n=5, by="ROI", min_bud=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.631499</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.604762</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.196549</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>13.501948</td>
#     </tr>
#     <tr>
#       <th>Despicable Me 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xL6t0Fo38DjiiuNLVSj58xJWNJy.jpg' style='height:100px;'></td>
#       <td>12.773183</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(n=5, by="ROI", min_bud=50, ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>0.001134</td>
#     </tr>
#     <tr>
#       <th>Metropolis</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3F5OKhpC6rqq5KdjgixNbqjWSWz.jpg' style='height:100px;'></td>
#       <td>0.007022</td>
#     </tr>
#     <tr>
#       <th>Lolita</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//unGWuk8kax8r4PlbGJL9y6WnfFx.jpg' style='height:100px;'></td>
#       <td>0.017098</td>
#     </tr>
#     <tr>
#       <th>Child 44</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qqGhMt31HVUN3WnH0L2r0OWq38E.jpg' style='height:100px;'></td>
#       <td>0.066487</td>
#     </tr>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>0.071040</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(n=5, by="Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.0</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.0</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.0</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>12000.0</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg' style='height:100px;'></td>
#       <td>11444.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(n=5, by= "Average Rating", min_votes = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.5</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.1</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.8</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//p64ilrhG8DPetzhVk10vuVjAG0t.jpg' style='height:100px;'></td>
#       <td>8.7</td>
#     </tr>
#     <tr>
#       <th>The Jinx: The Life and Deaths of Robert Durst</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jLqQrtpmB8RLqwuBDGR2OlLdoeC.jpg' style='height:100px;'></td>
#       <td>8.6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(n=5, by= "Average Rating", ascending = True, min_votes = 50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Manos: The Hands of Fate</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//dcDR1ZhZvA7HQvxQ17hzFjeCNHx.jpg' style='height:100px;'></td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>Birdemic: Shock and Terror</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lNC2Alq5CIIuPp1Bv0Y8hPHXZlP.jpg' style='height:100px;'></td>
#       <td>2.1</td>
#     </tr>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.8</td>
#     </tr>
#     <tr>
#       <th>Back in the Day</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eSLGYrj0IGgScf95TQB7JDX9k19.jpg' style='height:100px;'></td>
#       <td>2.8</td>
#     </tr>
#     <tr>
#       <th>An Eye for Beauty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//62PVBV9RZwLpGDK2IHwM32Zz25M.jpg' style='height:100px;'></td>
#       <td>2.9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(n=5, by="Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.488298</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.337037</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.253654</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rmnQ9jKW72bHu8uKlMjPIb2VLMI.jpg' style='height:100px;'></td>
#       <td>228.032744</td>
#     </tr>
#     <tr>
#       <th>Big Hero 6</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xozrGME58olN1xBhtxmjpOoY0jH.jpg' style='height:100px;'></td>
#       <td>213.849907</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
bruce = df.loc[mask_actor & mask_genres,["title","poster_path", "vote_average"]].sort_values(by = "vote_average", ascending= False)

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.3</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.6</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.5</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//v3Z0Hbl0oe57njrrIPh0fJPFoo.jpg' style='height:100px;'></td>
#       <td>5.9</td>
#     </tr>
#     <tr>
#       <th>20333</th>
#       <td>G.I. Joe: Retaliation</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//3rWIZMzTKcCtV0eHJ70Z4Ru659f.jpg' style='height:100px;'></td>
#       <td>5.4</td>
#     </tr>
#     <tr>
#       <th>27619</th>
#       <td>Vice</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//nPqNoQ55RIrmmo9mpqg1jE3ENza.jpg' style='height:100px;'></td>
#       <td>4.1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = df.director == "Quentin Tarantino"

# %%
mask_actor = df.cast.str.contains("Uma Thurman")

# %%
quentin = df.loc[mask_director & mask_actor, ["title", "poster_path", "runtime"]].sort_values(by = "runtime").set_index("title")

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.0</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.0</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
mask_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
mask_time = df.release_date.between("2010-01-01","2015-12-31")

# %%
pixar = df.loc[mask_studio & (df.release_date > '2009-12-31') & (df.release_date < '2016-01-01'), ["title", "poster_path", "release_date", "revenue_musd"]].sort_values(by = "revenue_musd", ascending= False).set_index("title")

# %%
pixar1 = df.loc[mask_studio & mask_time, ["title", "poster_path", "release_date", "revenue_musd"]].sort_values(by = "revenue_musd", ascending= False).set_index("title")

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>release_date</th>
#       <th>revenue_musd</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>2010-06-16</td>
#       <td>1066.969703</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>2015-06-09</td>
#       <td>857.611174</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>2013-06-20</td>
#       <td>743.559607</td>
#     </tr>
#     <tr>
#       <th>Cars 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//okIz1HyxeVOMzYwwHUjH2pHi74I.jpg' style='height:100px;'></td>
#       <td>2011-06-11</td>
#       <td>559.852396</td>
#     </tr>
#     <tr>
#       <th>Brave</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8l0pzWBrStFtbZiqeu0cGhxGKkT.jpg' style='height:100px;'></td>
#       <td>2012-06-21</td>
#       <td>538.983207</td>
#     </tr>
#     <tr>
#       <th>The Good Dinosaur</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8RSkxOO80btfKjyiC5ZiTaCHIT8.jpg' style='height:100px;'></td>
#       <td>2015-11-14</td>
#       <td>331.926147</td>
#     </tr>
#     <tr>
#       <th>Day & Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eQ1QUZfblOrusXVfbzzCuUaM7ix.jpg' style='height:100px;'></td>
#       <td>2010-06-17</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>The Blue Umbrella</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iSWV7ra8HJ3gYnZFMMrPe8CBbrv.jpg' style='height:100px;'></td>
#       <td>2013-02-12</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Toy Story of Terror!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aNDrMDZYmcoMlJa6K3VicYeAgt1.jpg' style='height:100px;'></td>
#       <td>2013-10-15</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>La luna</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iS6DB1hIRJHQPs9wWXvIzdnp7oD.jpg' style='height:100px;'></td>
#       <td>2011-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Hawaiian Vacation</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tByW10AkjWG0DtZwN2E2trT88DD.jpg' style='height:100px;'></td>
#       <td>2011-06-16</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Small Fry</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//z096FtMoUZxf9kqzSj39YE6psuD.jpg' style='height:100px;'></td>
#       <td>2011-11-23</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Partysaurus Rex</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ylj9TnXrTgiETysgBoSb8UQwEUc.jpg' style='height:100px;'></td>
#       <td>2012-09-14</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>The Legend of Mor'du</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8FKR6880g0JRiblbTQEijGlq3Qj.jpg' style='height:100px;'></td>
#       <td>2012-01-01</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Toy Story That Time Forgot</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jqQPN3X3aV5VmpTiEEASt36nlfi.jpg' style='height:100px;'></td>
#       <td>2014-12-02</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Lava</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//blZSkXNN4CzRBxdxXnz3YpUjnJp.jpg' style='height:100px;'></td>
#       <td>2015-06-21</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Sanjay's Super Team</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mShcGzOctlq6zs33UdrCdAwZMGq.jpg' style='height:100px;'></td>
#       <td>2015-11-25</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Air Mater</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jDwglSvFNBfWJNiyxD41CUcUic1.jpg' style='height:100px;'></td>
#       <td>2011-08-04</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Riley's First Date?</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//pyry5DuBCUiX02OtXRpPsjJ1r0L.jpg' style='height:100px;'></td>
#       <td>2015-11-03</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
#  14  runtime                43179 non-null  float64
#  15  overview               43740 non-null  object
#  16  spoken_languages       41094 non-null  object
#  17  poster_path            44467 non-null  object
#  18  cast                   42502 non-null  object
#  19  cast_size              44691 non-null  int64
#  20  crew_size              44691 non-null  int64
#  21  director               43960 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(12)
# memory usage: 7.5+ MB

# %%
mask_genre = df.genres.str.contains("Action") | df.genres.str.contains("Thriller")
mask_genre
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688     True
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
mask_lang = df.original_language == "en"

# %%
mask_vote = df.vote_average >= 7.5

# %%
mask_cnt = df.vote_count > 10

# %%
movies = df.loc[mask_genre & mask_lang & mask_vote & mask_cnt, ["title", "poster_path", "genres", "original_language", "vote_average", "vote_count", "release_date"]].sort_values(by = "release_date", ascending=False).set_index("title")

# %%
HTML(movies.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>original_language</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>en</td>
#       <td>7.5</td>
#       <td>171.0</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>en</td>
#       <td>7.5</td>
#       <td>2712.0</td>
#       <td>2017-07-19</td>
#     </tr>
#     <tr>
#       <th>The Book of Henry</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//suLFg4UjvM5BoDipg2Wu3gZ802T.jpg' style='height:100px;'></td>
#       <td>Thriller|Drama|Crime</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>84.0</td>
#       <td>2017-06-16</td>
#     </tr>
#     <tr>
#       <th>Guardians of the Galaxy Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg' style='height:100px;'></td>
#       <td>Action|Adventure|Comedy|Science Fiction</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>4858.0</td>
#       <td>2017-04-19</td>
#     </tr>
#     <tr>
#       <th>Logan</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fnbjcRDYn6YviCcePDnGdyAkYsB.jpg' style='height:100px;'></td>
#       <td>Action|Drama|Science Fiction</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>6310.0</td>
#       <td>2017-02-28</td>
#     </tr>
#     <tr>
#       <th>The Thinning</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//55yQMgLwJDyEom2Kose80JjTlDt.jpg' style='height:100px;'></td>
#       <td>Thriller</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>92.0</td>
#       <td>2016-10-12</td>
#     </tr>
#     <tr>
#       <th>11.22.63</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5EJGeeuPy19EGDy8HErpbHba0yq.jpg' style='height:100px;'></td>
#       <td>Drama|History|Thriller</td>
#       <td>en</td>
#       <td>8.0</td>
#       <td>213.0</td>
#       <td>2016-02-15</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>Action|Adventure|Science Fiction|Fantasy</td>
#       <td>en</td>
#       <td>7.5</td>
#       <td>7993.0</td>
#       <td>2015-12-15</td>
#     </tr>
#     <tr>
#       <th>London Spy</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//Ef9ZvB7p0BWJwEup7KE6x96NDw.jpg' style='height:100px;'></td>
#       <td>Romance|Crime|Drama|Mystery|Thriller</td>
#       <td>en</td>
#       <td>8.8</td>
#       <td>12.0</td>
#       <td>2015-11-09</td>
#     </tr>
#     <tr>
#       <th>Spotlight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//28Vnvn1WI1wJtP1kDqeRCZ1GdYm.jpg' style='height:100px;'></td>
#       <td>Drama|Thriller|History</td>
#       <td>en</td>
#       <td>7.8</td>
#       <td>2751.0</td>
#       <td>2015-11-06</td>
#     </tr>
#     <tr>
#       <th>Room</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//pCURNjeomWbMSdiP64gj8NVVHTQ.jpg' style='height:100px;'></td>
#       <td>Drama|Thriller</td>
#       <td>en</td>
#       <td>8.1</td>
#       <td>2838.0</td>
#       <td>2015-10-16</td>
#     </tr>
#     <tr>
#       <th>The Fear of 13</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//k5uLNLfmX5aUVm9uiYpAA1uj4BQ.jpg' style='height:100px;'></td>
#       <td>Thriller|Documentary</td>
#       <td>en</td>
#       <td>8.0</td>
#       <td>45.0</td>
#       <td>2015-10-15</td>
#     </tr>
#     <tr>
#       <th>3 ½ Minutes, 10 Bullets</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nUQDNzBp8IvqkvLYdCYsoQhaDaS.jpg' style='height:100px;'></td>
#       <td>Thriller|Documentary</td>
#       <td>en</td>
#       <td>7.8</td>
#       <td>30.0</td>
#       <td>2015-10-02</td>
#     </tr>
#     <tr>
#       <th>An Inspector Calls</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2e0zkY38Qykc69C4eK7uCMOIHfM.jpg' style='height:100px;'></td>
#       <td>Drama|Crime|Thriller</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>42.0</td>
#       <td>2015-09-13</td>
#     </tr>
#     <tr>
#       <th>Kung Fury</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nbWY6797LUxXRSYwamHp8V0X4dA.jpg' style='height:100px;'></td>
#       <td>Action|Comedy|Science Fiction|Fantasy</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>762.0</td>
#       <td>2015-05-22</td>
#     </tr>
#     <tr>
#       <th>Kingsman: The Secret Service</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//r6q9wZK5a2K51KFj4LWVID6Ja1r.jpg' style='height:100px;'></td>
#       <td>Crime|Comedy|Action|Adventure</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>6069.0</td>
#       <td>2015-01-29</td>
#     </tr>
#     <tr>
#       <th>Black Mirror: White Christmas</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//he609rnU3tiwBjRklKNa4n2jQSd.jpg' style='height:100px;'></td>
#       <td>Drama|Horror|Mystery|Science Fiction|Thriller|TV Movie</td>
#       <td>en</td>
#       <td>8.3</td>
#       <td>211.0</td>
#       <td>2014-12-16</td>
#     </tr>
#     <tr>
#       <th>The Imitation Game</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ntZGfHt4d73A9fDD4KUN4nbDQlq.jpg' style='height:100px;'></td>
#       <td>History|Drama|Thriller|War</td>
#       <td>en</td>
#       <td>8.0</td>
#       <td>5895.0</td>
#       <td>2014-11-14</td>
#     </tr>
#     <tr>
#       <th>Big Hero 6</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xozrGME58olN1xBhtxmjpOoY0jH.jpg' style='height:100px;'></td>
#       <td>Adventure|Family|Animation|Action|Comedy</td>
#       <td>en</td>
#       <td>7.8</td>
#       <td>6289.0</td>
#       <td>2014-10-24</td>
#     </tr>
#     <tr>
#       <th>Nightcrawler</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gYPIRu0jX2CGYdeO422cq3N78ju.jpg' style='height:100px;'></td>
#       <td>Crime|Drama|Thriller</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>3475.0</td>
#       <td>2014-10-23</td>
#     </tr>
#     <tr>
#       <th>Gone Girl</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tQf4DUygWo64AOuqgk4jEDCE3Ws.jpg' style='height:100px;'></td>
#       <td>Mystery|Thriller|Drama</td>
#       <td>en</td>
#       <td>7.9</td>
#       <td>6023.0</td>
#       <td>2014-10-01</td>
#     </tr>
#     <tr>
#       <th>Guardians of the Galaxy</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//r7vmZjiyZw9rpJMQJdXpjgiCOk9.jpg' style='height:100px;'></td>
#       <td>Action|Science Fiction|Adventure</td>
#       <td>en</td>
#       <td>7.9</td>
#       <td>10014.0</td>
#       <td>2014-07-30</td>
#     </tr>
#     <tr>
#       <th>Twin Peaks: Fire Walk with Me - The Missing Pieces</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//xQevnHeRxlQTfXQ5RxXJE4PnVUO.jpg' style='height:100px;'></td>
#       <td>TV Movie|Thriller|Drama|Crime</td>
#       <td>en</td>
#       <td>7.5</td>
#       <td>34.0</td>
#       <td>2014-07-29</td>
#     </tr>
#     <tr>
#       <th>How to Train Your Dragon 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d13Uj86LdbDLrfDoHR5aDOFYyJC.jpg' style='height:100px;'></td>
#       <td>Fantasy|Action|Adventure|Animation|Comedy|Family</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>3163.0</td>
#       <td>2014-06-12</td>
#     </tr>
#     <tr>
#       <th>Edge of Tomorrow</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uUHvlkLavotfGsNtosDy8ShsIYF.jpg' style='height:100px;'></td>
#       <td>Action|Science Fiction</td>
#       <td>en</td>
#       <td>7.6</td>
#       <td>4979.0</td>
#       <td>2014-05-27</td>
#     </tr>
#     <tr>
#       <th>X-Men: Days of Future Past</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vIpDpcF5j3xIx9w6cEzV20SW63S.jpg' style='height:100px;'></td>
#       <td>Action|Adventure|Fantasy|Science Fi

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
#  14  runtime                43179 non-null  float64
#  15  overview               43740 non-null  object
#  16  spoken_languages       41094 non-null  object
#  17  poster_path            44467 non-null  object
#  18  cast                   42502 non-null  object
#  19  cast_size              44691 non-null  int64
#  20  crew_size              44691 non-null  int64
#  21  director               43960 non-null  object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(12)
# memory usage: 7.5+ MB

# %%
df["Franchise_flag"]=df.belongs_to_collection.notna()

# %%
df.Franchise_flag.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise_flag, dtype: int64

# %%
df.groupby("Franchise_flag").revenue_musd.mean()
# Out:
# Franchise_flag
# False     44.742814
# True     165.708193
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)

# %%
df.groupby("Franchise_flag").ROI.median()
# Out:
# Franchise_flag
# False    1.619699
# True     3.709195
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby("Franchise_flag").budget_musd.mean()
# Out:
# Franchise_flag
# False    18.047741
# True     38.319847
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby("Franchise_flag").popularity.mean()
# Out:
# Franchise_flag
# False    2.592726
# True     6.245051
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby("Franchise_flag").vote_average.mean()
# Out:
# Franchise_flag
# False    6.008787
# True     5.956806
# Name: vote_average, dtype: float64

# %%
df.groupby("Franchise_flag").agg({"revenue_musd": "mean", "budget_musd":"mean", "ROI":"median", "popularity":"mean", "vote_average":"mean"})
# Out:
#                 revenue_musd  budget_musd       ROI  popularity  vote_average
# Franchise_flag
# False              44.742814    18.047741  1.619699    2.592726      6.008787
# True              165.708193    38.319847  3.709195    6.245051      5.956806

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                        29
# Totò Collection                        27
# Zatôichi: The Blind Swordsman          26
# James Bond Collection                  26
# The Carry On Collection                25
#                                        ..
# Yamakasi - Collection                   1
# Никто не знает про секс - Коллекция     1
# Горько! (Коллекция)                     1
# Truth in 24 Collection                  1
# Trinità  Collection                     1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"title":"count", "budget_musd":["sum","mean"],  "revenue_musd":["sum","mean"], "ROI":"median", "popularity":"mean", "vote_average":"mean", "vote_count":"mean"})

# %%
franchises.nlargest(20, ("title", "count"))
# Out:
#                                        title budget_musd             \
#                                        count         sum       mean
# belongs_to_collection
# The Bowery Boys                           29      0.0000        NaN
# Totò Collection                           27      0.0000        NaN
# James Bond Collection                     26   1539.6500  59.217308
# Zatôichi: The Blind Swordsman             26      0.0000        NaN
# The Carry On Collection                   25      0.0000        NaN
# Charlie Chan (Sidney Toler) Collection    21      0.0000        NaN
# Pokémon Collection                        20    250.7204  50.144080
# Godzilla (Showa) Collection               16      2.8100   0.562000
# Charlie Chan (Warner Oland) Collection    15      0.0000        NaN
# Dragon Ball Z (Movie) Collection          15      5.0000   5.000000
# Uuno Turhapuro                            15      0.0000        NaN
# Monster High Collection                   14      0.5000   0.500000
# The Land Before Time Collection           14     12.3000  12.300000
# George Carlin Comedy Collection           13      0.0000        NaN
# Sharpe Collection                         13      0.0000        NaN
# Friday the 13th Collection                12     84.4000   7.033333
# Johan Falk GSI Collection                 12      0.0000        NaN
# Sherlock Holmes (1939 series)             12      0.0000        NaN
# The Amityville Horror Collection          12     21.0200   5.255000
# An American Girl Collection               10      6.8000   6.800000
#
#                                        revenue_musd                    ROI  \
#                                                 sum        mean     median
# belongs_to_collection
# The Bowery Boys                            0.000000         NaN        NaN
# Totò Collection                            0.000000         NaN        NaN
# James Bond Collection                   7106.970239  273.345009   6.128922
# Zatôichi: The Blind Swordsman              0.000000         NaN        NaN
# The Carry On Collection                    0.000000         NaN        NaN
# Charlie Chan (Sidney Toler) Collection     0.000000         NaN        NaN
# Pokémon Collection                       601.865958   66.873995   4.464976
# Godzilla (Showa) Collection                0.000000         NaN        NaN
# Charlie Chan (Warner Oland) Collection     0.000000         NaN        NaN
# Dragon Ball Z (Movie) Collection         112.121192   56.060596  12.353638
# Uuno Turhapuro                             0.000000         NaN        NaN
# Monster High Collection                    0.000000         NaN        NaN
# The Land Before Time Collection           84.460846   84.460846   6.866735
# George Carlin Comedy Collection            0.000000         NaN        NaN
# Sharpe Collection                          0.000000         NaN        NaN
# Friday the 13th Collection               464.898544   38.741545   6.668557
# Johan Falk GSI Collection                  0.000000         NaN        NaN
# Sherlock Holmes (1939 series)              0.000000         NaN        NaN
# The Amityville Horror Collection         213.347083   53.336771   5.686691
# An American Girl Collection                0.000000         NaN        NaN
#
#                                        popularity vote_average   vote_count
#                                              mean         mean         mean
# belongs_to_collection
# The Bowery Boys                          0.198006     6.675000     0.724138
# Totò Collection                          1.047324     6.837037    18.037037
# James Bond Collection                   13.453502     6.338462  1284.307692
# Zatôichi: The Blind Swordsman            1.100603     6.403846    11.192308
# The Carry On Collection                  3.220430     6.168000    21.040000
# Charlie Chan (Sidney Toler) Collection   0.630996     6.609524     5.809524
# Pokémon Collection                       4.374284     6.055000    71.100000
# Godzilla (Showa) Collection              3.422842     5.975000    39.750000
# Charlie Chan (Warner Oland) Collection   0.664986     6.658333     6.866667
# Dragon Ball Z (Movie) Collection         6.183563     6.606667   133.333333
# Uuno Turhapuro                           0.169261     5.526667     3.866667
# Monster High Collection                  3.591922     6.485714    12.571429
# The Land Before Time Collection          4.905620     6.164286    96.071429
# George Carlin Comedy Collection          1.296917     7.469231    12.538462
# Sharpe Collection                        1.709641     6.738462    13.230769
# Friday the 13th Collection               9.760807     5.425000   326.583333
# Johan Falk GSI Collection                1.520858     6.500000     9.250000
# Sherlock Holmes (1939 series)            2.876897     6.925000    21.583333
# The Amityville Horror Collection         7.179849     4.358333    91.916667
# An American Girl Collection              1.940739     5.250000     8.700000

# %%
franchises[franchises[("vote_count", "mean")] >=1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00   88.666667
# The Godfather Collection                3       73.00   24.333333
# Blade Runner Collection                 1       28.00   28.000000
# The Man With No Name Collection         3        2.00    0.666667
# The Dark Knight Collection              3      585.00  195.000000
# Guardians of the Galaxy Collection      2      370.00  185.000000
# Kill Bill Collection                    2       60.00   30.000000
# Kingsman Collection                     1       81.00   81.000000
# How to Train Your Dragon Collection     2      310.00  155.000000
# Harry Potter Collection                 8     1280.00  160.000000
# Toy Story Collection                    3      320.00  106.666667
# Back to the Future Collection           3       99.00   33.000000
# Trainspotting Collection                2       22.00   11.000000
# Deadpool Collection                     1       58.00   58.000000
# The Incredibles Collection              1       92.00   92.000000
# Star Wars Collection                    8      854.35  106.793750
# The Avengers Collection                 2      500.00  250.000000
# The Lego Movie Collection               2      140.00   70.000000
# Tangled Collection                      2      260.00  260.000000
# The Space Odyssey Series                2       38.50   19.250000
#
#                                     revenue_musd                     ROI  \
#                                              sum         mean     median
# belongs_to_collection
# The Lord of the Rings Collection     2916.544743   972.181581  11.725157
# The Godfather Collection              429.375314   143.125105   3.657142
# Blade Runner Collection                33.139618    33.139618   1.183558
# The Man With No Name Collection        35.500000    11.833333  25.000000
# The Dark Knight Collection           2463.716216   821.238739   4.339756
# Guardians of the Galaxy Collection   1636.744770   818.372385   4.433036
# Kill Bill Collection                  333.108461   166.554231   5.551808
# Kingsman Collection                   414.351546   414.351546   5.115451
# How to Train Your Dragon Collection  1104.001807   552.000904   3.600057
# Harry Potter Collection              7707.367425   963.420928   6.165086
# Toy Story Collection                 1937.890605   645.963535   5.526299
# Back to the Future Collection         957.637345   319.212448   8.300000
# Trainspotting Collection               57.903789    28.951895   3.211738
# Deadpool Collection                   783.112979   783.112979  13.501948
# The Incredibles Collection            631.442092   631.442092   6.863501
# Star Wars Collection                 7434.494790   929.311849   8.239637
# The Avengers Collection              2924.961604  1462.480802   5.963190
# The Lego Movie Collection             781.111076   390.555538   5.859362
# Tangled Collection                    591.794936   591.794936   2.276134
# The Space Odyssey Series              109.100657    54.550329   3.992869
#
#                                      popularity vote_average    vote_count
#                                            mean         mean          mean
# belongs_to_collection
# The Lord of the Rings Collection      30.272873     8.033333   8253.000000
# The Godfather Collection              31.641307     7.966667   3677.000000
# Blade Runner Collection               96.272374     7.900000   3833.000000
# The Man With No Name Collection       14.171278     7.833333   1422.666667
# The Dark Knight Collection            57.418393     7.800000   9681.000000
# Guardians of the Galaxy Collection   119.311296     7.750000   7436.000000
# Kill Bill Collection                  23.397469     7.700000   4576.000000
# Kingsman Collection                   28.224212     7.600000   6069.000000
# How to Train Your Dragon Collection   13.336685     7.550000   3741.000000
# Harry Potter Collection               26.253893     7.537500   5983.250000
# Toy Story Collection                  18.820369     7.533333   4679.666667
# Back to the Future Collection         17.504121     7.500000   4381.000000
# Trainspotting Collection              18.497172     7.450000   1766.000000
# Deadpool Collection                  187.860492     7.400000  11444.000000
# The Incredibles Collection            22.220214     7.400000   5290.000000
# Star Wars Collection                  23.410919     7.375000   5430.375000
# The Avengers Collection               63.633534     7.350000   9454.000000
# The Lego Movie Collection             16.744440     7.350000   2300.000000
# Tangled Collection                    12.319364     7.250000   1901.000000
# The Space Odyssey Series              14.988743     7.250000   1682.500000

# %%
franchises[franchises.vote_count.mean() >=1000].nlargest(20, ("vote_average", "mean"))
# Out:
# <ipython-input-94-9b6d4e02fc60>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   franchises[franchises.vote_count.mean() >=1000].nlargest(20, ("vote_average", "mean"))
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-94-9b6d4e02fc60> in <module>
# ----> 1 franchises[franchises.vote_count.mean() >=1000].nlargest(20, ("vote_average", "mean"))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2841         # check_bool_indexer will throw exception if Series key cannot
#    2842         # be reindexed to match DataFrame rows
# -> 2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
#    2845         return self._take_with_is_copy(indexer, axis=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2315         mask = isna(result._values)
#    2316         if mask.any():
# -> 2317             raise IndexingError(
#    2318                 "Unalignable boolean Series provided as "
#    2319                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
#  14  runtime                43179 non-null  float64
#  15  overview               43740 non-null  object
#  16  spoken_languages       41094 non-null  object
#  17  poster_path            44467 non-null  object
#  18  cast                   42502 non-null  object
#  19  cast_size              44691 non-null  int64
#  20  crew_size              44691 non-null  int64
#  21  director               43960 non-null  object
#  22  Franchise_flag         44691 non-null  bool
#  23  ROI                    5371 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(7), int64(3), object(12)
# memory usage: 7.9+ MB

# %%
df["ROI_flag"] = df.ROI >= 1.0

# %%
df["ROI_flag"]
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: ROI_flag, Length: 44691, dtype: bool

# %%
directors = df[df["ROI"] > 1.0].groupby("director").agg({"title":"count", "revenue_musd":"sum", "vote_average":"mean", "vote_count":"mean"})

# %% [markdown]
# ## Most Successful Directors

# %%
directors
# Out:
#                           title  revenue_musd  vote_average   vote_count
# director
# A.R. Murugadoss               2    174.900000      6.750000    47.000000
# Aamir Khan                    1     28.430000      7.700000   194.000000
# Aaron Katz                    1      0.015425      6.600000     7.000000
# Abbas Alibhai Burmawalla      1      9.250000      4.900000    17.000000
# Abbas Tyrewala                1     11.100000      6.700000    37.000000
# ...                         ...           ...           ...          ...
# Zacharias Kunuk               1      3.786801      6.300000    21.000000
# Zack Snyder                   7   2476.197387      6.485714  3578.571429
# Zana Briski                   1      3.515061      6.700000    61.000000
# Zhang Yimou                   3    604.662971      6.733333   768.333333
# Zoya Akhtar                   1     22.000000      6.700000    43.000000
#
# [1748 rows x 4 columns]

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
directors.nlargest(5, ("title"))
# Out:
#                   title  revenue_musd  vote_average   vote_count
# director
# Steven Spielberg     28   9202.626984      6.978571  2187.214286
# Clint Eastwood       24   2927.859573      6.854167   932.375000
# Alfred Hitchcock     21    250.107584      7.361905   527.809524
# Ridley Scott         18   3826.088024      6.722222  2333.388889
# Woody Allen          18    861.845172      6.866667   618.500000

# %% [markdown]
# ## Most Successful Actors

# %%
df.set_index("id", inplace=True)

# %%
act = df.cast.str.split("|", expand = True)

# %%
act = act.stack().reset_index(level=1, drop=True).to_frame()

# %%
act.columns = ["Actor"]

# %%
act = act.merge(df[["title", "revenue_musd", "vote_average", "popularity"]], how="left", left_index=True, right_index=True)

# %%
act.revenue_musd.fillna(0, inplace= True)
act.vote_average.fillna(0, inplace= True)

# %%
act.Actor.value_counts().head(20)
# Out:
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# John Carradine        109
# Gérard Depardieu      109
# Jackie Chan           108
# Donald Sutherland     108
# Frank Welker          107
# Robert De Niro        104
# Steve Buscemi         101
# Danny Trejo           101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Dennis Hopper          92
# Susan Sarandon         92
# Name: Actor, dtype: int64

# %%
plt.figure(figsize = (12,8))
act.Actor.value_counts().head(20).plot(kind='bar', fontsize=15)
plt.title("Most Active Actors", fontsize= 20)
plt.ylabel("Number of Movies", fontsize= 15)
plt.show()

# %%
agg = act.groupby("Actor").agg(Total_Revenue = ("revenue_musd", "sum"), Mean_Revenue = ("revenue_musd", "mean"), Mean_Rating=("vote_average", "mean"),
                              Mean_pop = ("popularity", "mean"), Total_Movies = ("Actor", "count"))

# %%
agg.nlargest(10, "Total_Movies")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating   Mean_pop  \
# Actor
# Bess Flowers          368.913259      1.537139     5.540000   2.030528
# Christopher Lee      9417.047887     63.628702     5.870270   4.749606
# John Wayne            236.094000      1.888752     5.666400   3.092939
# Samuel L. Jackson   17109.620672    140.242792     6.214754  11.703945
# Michael Caine        8053.404838     73.212771     6.155455   8.265272
# Gérard Depardieu     1247.608953     11.445954     6.053211   3.703836
# John Carradine        255.839586      2.347152     5.343119   2.434950
# Donald Sutherland    5390.766679     49.914506     6.118519   7.003230
# Jackie Chan          4699.185933     43.510981     6.217593   5.862638
# Frank Welker        13044.152470    121.907967     6.251402   9.571404
#
#                    Total_Movies
# Actor
# Bess Flowers                240
# Christopher Lee             148
# John Wayne                  125
# Samuel L. Jackson           122
# Michael Caine               110
# Gérard Depardieu            109
# John Carradine              109
# Donald Sutherland           108
# Jackie Chan                 108
# Frank Welker                107

# %%
agg.nlargest(10, "Total_Revenue")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating   Mean_pop  \
# Actor
# Stan Lee            19414.957555    404.478282     6.241667  29.936175
# Samuel L. Jackson   17109.620672    140.242792     6.214754  11.703945
# Warwick Davis       13256.032188    389.883300     6.294118  13.088614
# Frank Welker        13044.152470    121.907967     6.251402   9.571404
# John Ratzenberger   12596.126073    273.828828     6.343478  10.959477
# Jess Harnell        12234.608163    349.560233     6.251429  10.919015
# Hugo Weaving        11027.578473    275.689462     6.150000  10.967890
# Ian McKellen        11015.592318    250.354371     6.209091  15.447180
# Johnny Depp         10653.760641    154.402328     6.440580  12.378196
# Alan Rickman        10612.625348    235.836119     6.715556  10.399285
#
#                    Total_Movies
# Actor
# Stan Lee                     48
# Samuel L. Jackson           122
# Warwick Davis                34
# Frank Welker                107
# John Ratzenberger            46
# Jess Harnell                 35
# Hugo Weaving                 40
# Ian McKellen                 44
# Johnny Depp                  69
# Alan Rickman                 45

# %%
plt.figure(figsize = (12,8))
agg.Total_Revenue.nlargest(10).plot(kind='bar', fontsize= 15)
plt.title("Total Revenue", fontsize=20)
plt.ylabel("Revenue (in MUSD)", fontsize=15)
plt.show()

# %%
from wordcloud import WordCloud

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 44686         Rising and falling between a man and woman          NaT
# 44687                                                NaN   2011-11-17
# 44688                             A deadly game of wits.   2003-08-01
# 44689                                                NaN   1917-10-21
# 44690                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 44686              Drama|Family                             NaN
# 44687                     Drama                             NaN
# 44688     Action|Drama|Thriller                             NaN
# 44689                       NaN                             NaN
# 44690                       NaN                             NaN
#
#       original_language  budget_musd  revenue_musd  \
# 0                    en         30.0    373.554033
# 1                    en         65.0    262.797249
# 2                    en          NaN           NaN
# 3                    en         16.0     81.452156
# 4                    en          NaN     76.578911
# ...                 ...          ...           ...
# 44686                fa          NaN           NaN
# 44687                tl          NaN           NaN
# 44688                en          NaN           NaN
# 44689                en          NaN           NaN
# 44690                en          NaN           NaN
#
#                                     production_companies  ... vote_average  \
# 0                                Pixar Animation Studios  ...          7.7
# 1      TriStar Pictures|Teitler Film|Interscope Commu...  ...          6.9
# 2                            Warner Bros.|Lancaster Gate  ...          6.5
# 3                 Twentieth Century Fox Film Corporation  ...          6.1
# 4              Sandollar Productions|Touchstone Pictures  ...          5.7
# ...                                                  ...  ...          ...
# 44686                                                NaN  ...          4.0
# 44687                                        Sine Olivia  ...          9.0
# 44688                            American World Pictures  ...          3.8
# 44689                                          Yermoliev  ...          NaN
# 44690                                                NaN  ...          NaN
#
#        popularity  runtime                                           overview  \
# 0       21.946943     81.0  Led by Woody, Andy's toys live happily in his ...
# 1       17.015539    104.0  When siblings Judy and Peter discover an encha...
# 2       11.712900    101.0  A family wedding reignites the ancient feud be...
# 3        3.859495    127.0  Cheated on, mistreated and stepped on, the wom...
# 4        8.387519    106.0  Just when George Banks has recovered from his ...
# ...           ...      ...                                                ...
# 44686    0.072051     90.0        Rising and falling between a man and woman.
# 44687    0.178241    360.0  An artist struggles to finish his work while a...
# 44688    0.903007     90.0  When one of her hits goes wrong, a professiona...
# 44689    0.003503     87.0  In a small town live two brothers, one a minis...
# 44690    0.163015     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                                        poster_path  \
# 0               English  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      English|Français  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2               English  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3               English  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4               English  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                 ...                                                ...
# 44686             فارسی  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687               NaN  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688           English  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689               NaN  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690           English  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                                     cast cast_size crew_size  \
# 0      Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13       106
# 1      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26        16
# 2      Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7         4
# 3      Whitney Houston|Angela Bassett|Loretta Devine|...        10        10
# 4      Steve Martin|Diane Keaton|Martin Short|Kimberl...        12         7
# ...                                                  ...       ...       ...
# 44686            Leila Hatami|Kourosh Tahami|Elham Korda         3         9
# 44687  Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...        11         6
# 44688  Erika Eleniak|Adam Baldwin|Julie du Page|James...        15         5
# 44689  Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...         5         2
# 44690                                                NaN         0         1
#
#                director
# 0         John Lasseter
# 1          Joe Johnston
# 2         Howard Deutch
# 3       Forest Whitaker
# 4         Charles Shyer
# ...                 ...
# 44686  Hamid Nematollah
# 44687          Lav Diaz
# 44688    Mark L. Lester
# 44689  Yakov Protazanov
# 44690     Daisy Asquith
#
# [44691 rows x 22 columns]

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline = df.tagline.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object

# %%
title_corpus = ' '.join(title)
overview_corpus = ' '.join(overview)
tagline_corpus = ' '.join(tagline)

# %%
title_wc = WordCloud(background_color='white', height=2000, width=4000, max_words=50).generate(title_corpus)
title_wc

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
tagline_wc = WordCloud(background_color='white', height=2000, width=4000, max_words=100).generate(tagline_corpus)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
overview_wc = WordCloud(background_color='white', height=2000, width=4000, max_words=100).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wc, interpolation="bilinear")
plt.axis('off')
plt.show()
